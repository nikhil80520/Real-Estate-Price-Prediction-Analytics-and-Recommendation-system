# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\asus\OneDrive\Desktop\dataset\gurgaon_properties.csv")

# %%
df
# Out:
#                                       property_name property_type  \
# 0                      2 BHK Flat in Krishna Colony          flat
# 1                         2 BHK Flat in Ashok Vihar          flat
# 2                               2 BHK Flat in Sohna          flat
# 3                   2 BHK Flat in Sector 61 Gurgaon          flat
# 4                   2 BHK Flat in Sector 92 Gurgaon          flat
# ...                                             ...           ...
# 3949  4 Bedroom House for sale in Sector 26 Gurgaon         house
# 3950        3 Bedroom House for sale in DLF Phase 2         house
# 3951  3 Bedroom House for sale in Sector 26 Gurgaon         house
# 3952  3 Bedroom House for sale in Sector 26 Gurgaon         house
# 3953             3 Bedroom House for sale in Bissar         house
#
#                                        society  price  price_per_sqft  \
# 0                       maa bhagwati residency   0.45          5000.0
# 1                                 apna enclave   0.50          7692.0
# 2                       tulsiani easy in homes   0.40          6722.0
# 3                          smart world orchard   1.47         12250.0
# 4                             parkwood westend   0.70          5204.0
# ...                                        ...    ...             ...
# 3949                          dlf city phase 1   5.50         30556.0
# 3950                    dlf city plots phase 2   4.25         31481.0
# 3951                          dlf city phase 1   4.50         33333.0
# 3952                          dlf city phase 1   3.25         33129.0
# 3953  silverglades tarudhan valley golf resort   3.60         14815.0
#
#              area                            areaWithType  bedRoom  bathroom  \
# 0      900.000000          Carpet area: 900 (83.61 sq.m.)        2         2
# 1      650.026001          Carpet area: 650 (60.39 sq.m.)        2         2
# 2      595.060994          Carpet area: 595 (55.28 sq.m.)        2         2
# 3     1200.000000        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4     1345.119139  Super Built up area 1345(124.95 sq.m.)        2         2
# ...           ...                                     ...      ...       ...
# 3949  1800.000000             Plot area 200(167.23 sq.m.)        4         4
# 3950  1350.000000             Plot area 150(125.42 sq.m.)        3         2
# 3951  1350.000000             Plot area 150(125.42 sq.m.)        3         3
# 3952   981.000000              Plot area 109(91.14 sq.m.)        3         3
# 3953  2430.000000             Plot area 270(225.75 sq.m.)        3         3
#
#      balcony  ...                              address floorNum      facing  \
# 0          1  ...     Krishna Colony, Gurgaon, Haryana      4.0        West
# 1          1  ...   46b, Ashok Vihar, Gurgaon, Haryana      1.0        West
# 2          3  ...              Sohna, Gurgaon, Haryana     12.0         NaN
# 3          2  ...  Sector 61 Gurgaon, Gurgaon, Haryana      2.0         NaN
# 4          3  ...  Sector 92 Gurgaon, Gurgaon, Haryana      5.0         NaN
# ...      ...  ...                                  ...      ...         ...
# 3949       3  ...  Sector 26 Gurgaon, Gurgaon, Haryana      NaN  North-East
# 3950       3  ...        DLF Phase 2, Gurgaon, Haryana      NaN       North
# 3951       2  ...  Sector 26 Gurgaon, Gurgaon, Haryana      NaN        East
# 3952       3  ...  Sector 26 Gurgaon, Gurgaon, Haryana      NaN        West
# 3953       2  ...             Bissar, Gurgaon, Haryana      NaN         NaN
#
#            agePossession                                    nearbyLocations  \
# 0        1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1           10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2        0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
# 3                 Dec-23  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4     Under Construction  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# ...                  ...                                                ...
# 3949    5 to 10 Year Old  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3950        10+ Year Old  ['Sahara Mall', 'Delhi Public School', 'Privat...
# 3951    5 to 10 Year Old  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3952        10+ Year Old  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3953    5 to 10 Year Old                                                NaN
#
#                                             description  \
# 0     So with lift.Maa bhagwati residency is one of ...
# 1     Property situated on main road, railway statio...
# 2     This property is 15 km away from badshapur, gu...
# 3     Near to metro station of sector 56 and opposit...
# 4     We are the proud owners of this 2 bhk alongwit...
# ...                                                 ...
# 3949  Residential house, g block, dlf phase-1, gurga...
# 3950  Residential house, k block, dlf phase-2, gurga...
# 3951  Residential house, e block 150 sq.Yds , dlf ph...
# 3952  Residential house, e block, dlf phase-1, gurga...
# 3953  This 3 bhk house for sale in bissar is an idea...
#
#                                          furnishDetails  \
# 0     ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1     ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    []
# ...                                                 ...
# 3949  ['10 Light', 'No AC', 'No Bed', 'No Chimney', ...
# 3950                                                NaN
# 3951  ['6 Fan', '20 Light', 'No AC', 'No Bed', 'No C...
# 3952  ['5 Fan', '16 Light', 'No AC', 'No Bed', 'No C...
# 3953  ['1 Water Purifier', '10 Fan', '1 Fridge', '1 ...
#
#                                                features  \
# 0     ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1     ['Security / Fire Alarm', 'Maintenance Staff',...
# 2     ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3     ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                   NaN
# ...                                                 ...
# 3949  ['Feng Shui / Vaastu Compliant', 'High Ceiling...
# 3950  ['High Ceiling Height', 'Maintenance Staff', '...
# 3951  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3952  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3953  ['Centrally Air Conditioned', 'Water purifier'...
#
#                                                  rating noOfFloor
# 0     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 1     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 2     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 3                                                   NaN       NaN
# 4     ['Environment5 out of 5', 'Safety3 out of 5', ...       NaN
# ...                                                 ...       ...
# 3949                                                NaN       2.0
# 3950  ['Environment5 out of 5', 'Safety5 out of 5', ...       2.0
# 3951                                                NaN       2.0
# 3952                                                NaN       2.0
# 3953                                                NaN       2.0
#
# [3954 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3954 entries, 0 to 3953
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3954 non-null   object
#  1   property_type    3954 non-null   object
#  2   society          3953 non-null   object
#  3   price            3954 non-null   float64
#  4   price_per_sqft   3954 non-null   float64
#  5   area             3954 non-null   float64
#  6   areaWithType     3954 non-null   object
#  7   bedRoom          3954 non-null   int64
#  8   bathroom         3954 non-null   int64
#  9   balcony          3954 non-null   object
#  10  additionalRoom   3954 non-null   object
#  11  address          3943 non-null   object
#  12  floorNum         2991 non-null   float64
#  13  facing           2782 non-null   object
#  14  agePossession    3953 non-null   object
#  15  nearbyLocations  3748 non-null   object
#  16  description      3954 non-null   object
#  17  furnishDetails   2926 non-null   object
#  18  features         3248 non-null   object
#  19  rating           3506 non-null   object
#  20  noOfFloor        938 non-null    float64
# dtypes: float64(5), int64(2), object(14)
# memory usage: 648.8+ KB

# %%
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                 0
# price_per_sqft        0
# area                  0
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum            963
# facing             1172
# agePossession         1
# nearbyLocations     206
# description           0
# furnishDetails     1028
# features            706
# rating              448
# noOfFloor          3016
# dtype: int64

# %%
df['property_name'].value_counts()
# Out:
# property_name
# 2 BHK Flat in Sohna                                    125
# 3 BHK Flat in Sector 102 Gurgaon                        76
# 3 BHK Flat in Sector 65 Gurgaon                         57
# 3 BHK Flat in Sector 92 Gurgaon                         53
# 3 BHK Flat in Sector 69 Gurgaon                         51
#                                                       ...
# 4 Bedroom House for sale in Part 3 Sector 5 Gurgaon      1
# 4 BHK Flat in Sushant Lok Phase 1                        1
# 10 Bedroom House for sale in Ravi Nagar                  1
# 6 Bedroom House for sale in Farukhnagar                  1
# 4 Bedroom House for sale in Ansal's Palam Vihar          1
# Name: count, Length: 942, dtype: int64

# %%
df.insert(loc=3,column='sector',value=df['property_name'].str.split("in").str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df
# Out:
#                                       property_name property_type  \
# 0                      2 BHK Flat in Krishna Colony          flat
# 1                         2 BHK Flat in Ashok Vihar          flat
# 2                               2 BHK Flat in Sohna          flat
# 3                   2 BHK Flat in Sector 61 Gurgaon          flat
# 4                   2 BHK Flat in Sector 92 Gurgaon          flat
# ...                                             ...           ...
# 3949  4 Bedroom House for sale in Sector 26 Gurgaon         house
# 3950        3 Bedroom House for sale in DLF Phase 2         house
# 3951  3 Bedroom House for sale in Sector 26 Gurgaon         house
# 3952  3 Bedroom House for sale in Sector 26 Gurgaon         house
# 3953             3 Bedroom House for sale in Bissar         house
#
#                                        society          sector  price  \
# 0                       maa bhagwati residency  Krishna Colony   0.45
# 1                                 apna enclave     Ashok Vihar   0.50
# 2                       tulsiani easy in homes           Sohna   0.40
# 3                          smart world orchard       Sector 61   1.47
# 4                             parkwood westend       Sector 92   0.70
# ...                                        ...             ...    ...
# 3949                          dlf city phase 1       Sector 26   5.50
# 3950                    dlf city plots phase 2     DLF Phase 2   4.25
# 3951                          dlf city phase 1       Sector 26   4.50
# 3952                          dlf city phase 1       Sector 26   3.25
# 3953  silverglades tarudhan valley golf resort          Bissar   3.60
#
#       price_per_sqft         area                            areaWithType  \
# 0             5000.0   900.000000          Carpet area: 900 (83.61 sq.m.)
# 1             7692.0   650.026001          Carpet area: 650 (60.39 sq.m.)
# 2             6722.0   595.060994          Carpet area: 595 (55.28 sq.m.)
# 3            12250.0  1200.000000        Carpet area: 1200 (111.48 sq.m.)
# 4             5204.0  1345.119139  Super Built up area 1345(124.95 sq.m.)
# ...              ...          ...                                     ...
# 3949         30556.0  1800.000000             Plot area 200(167.23 sq.m.)
# 3950         31481.0  1350.000000             Plot area 150(125.42 sq.m.)
# 3951         33333.0  1350.000000             Plot area 150(125.42 sq.m.)
# 3952         33129.0   981.000000              Plot area 109(91.14 sq.m.)
# 3953         14815.0  2430.000000             Plot area 270(225.75 sq.m.)
#
#       bedRoom  bathroom  ...                              address floorNum  \
# 0           2         2  ...     Krishna Colony, Gurgaon, Haryana      4.0
# 1           2         2  ...   46b, Ashok Vihar, Gurgaon, Haryana      1.0
# 2           2         2  ...              Sohna, Gurgaon, Haryana     12.0
# 3           2         2  ...  Sector 61 Gurgaon, Gurgaon, Haryana      2.0
# 4           2         2  ...  Sector 92 Gurgaon, Gurgaon, Haryana      5.0
# ...       ...       ...  ...                                  ...      ...
# 3949        4         4  ...  Sector 26 Gurgaon, Gurgaon, Haryana      NaN
# 3950        3         2  ...        DLF Phase 2, Gurgaon, Haryana      NaN
# 3951        3         3  ...  Sector 26 Gurgaon, Gurgaon, Haryana      NaN
# 3952        3         3  ...  Sector 26 Gurgaon, Gurgaon, Haryana      NaN
# 3953        3         3  ...             Bissar, Gurgaon, Haryana      NaN
#
#           facing       agePossession  \
# 0           West     1 to 5 Year Old
# 1           West        10+ Year Old
# 2            NaN     0 to 1 Year Old
# 3            NaN              Dec-23
# 4            NaN  Under Construction
# ...          ...                 ...
# 3949  North-East    5 to 10 Year Old
# 3950       North        10+ Year Old
# 3951        East    5 to 10 Year Old
# 3952        West        10+ Year Old
# 3953         NaN    5 to 10 Year Old
#
#                                         nearbyLocations  \
# 0     ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1     ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2     ['Huda City Metro', 'Golf Course extn road', '...
# 3     ['Sector 55-56 Metro station', 'Bestech Centra...
# 4     ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# ...                                                 ...
# 3949  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3950  ['Sahara Mall', 'Delhi Public School', 'Privat...
# 3951  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3952  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3953                                                NaN
#
#                                             description  \
# 0     So with lift.Maa bhagwati residency is one of ...
# 1     Property situated on main road, railway statio...
# 2     This property is 15 km away from badshapur, gu...
# 3     Near to metro station of sector 56 and opposit...
# 4     We are the proud owners of this 2 bhk alongwit...
# ...                                                 ...
# 3949  Residential house, g block, dlf phase-1, gurga...
# 3950  Residential house, k block, dlf phase-2, gurga...
# 3951  Residential house, e block 150 sq.Yds , dlf ph...
# 3952  Residential house, e block, dlf phase-1, gurga...
# 3953  This 3 bhk house for sale in bissar is an idea...
#
#                                          furnishDetails  \
# 0     ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1     ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    []
# ...                                                 ...
# 3949  ['10 Light', 'No AC', 'No Bed', 'No Chimney', ...
# 3950                                                NaN
# 3951  ['6 Fan', '20 Light', 'No AC', 'No Bed', 'No C...
# 3952  ['5 Fan', '16 Light', 'No AC', 'No Bed', 'No C...
# 3953  ['1 Water Purifier', '10 Fan', '1 Fridge', '1 ...
#
#                                                features  \
# 0     ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1     ['Security / Fire Alarm', 'Maintenance Staff',...
# 2     ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3     ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                   NaN
# ...                                                 ...
# 3949  ['Feng Shui / Vaastu Compliant', 'High Ceiling...
# 3950  ['High Ceiling Height', 'Maintenance Staff', '...
# 3951  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3952  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3953  ['Centrally Air Conditioned', 'Water purifier'...
#
#                                                  rating noOfFloor
# 0     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 1     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 2     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 3                                                   NaN       NaN
# 4     ['Environment5 out of 5', 'Safety3 out of 5', ...       NaN
# ...                                                 ...       ...
# 3949                                                NaN       2.0
# 3950  ['Environment5 out of 5', 'Safety5 out of 5', ...       2.0
# 3951                                                NaN       2.0
# 3952                                                NaN       2.0
# 3953                                                NaN       2.0
#
# [3954 rows x 22 columns]

# %%
df['sector']=df['sector'].str.lower()

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna                          163
# sector 102                     113
# sector 85                      110
# sector 92                      104
# sector 69                       94
#                               ...
# lucknow                          1
# part 3 sector 5                  1
# near sector 1 market             1
# saroop garden rajendra park      1
# carterpuri village               1
# Name: count, Length: 299, dtype: int64

# %%
df['sector']=df['sector'].str.replace('dharam colony','sector 12')
df['sector']=df['sector'].str.replace('krishna colony','sector 7')
df['sector']=df['sector'].str.replace('suncity','sector 54')
df['sector']=df['sector'].str.replace('prem nagar','sector 13')
df['sector']=df['sector'].str.replace('mg road','sector 28')
df['sector']=df['sector'].str.replace('gandhi nagar','sector 28')
df['sector']=df['sector'].str.replace('laxmi garden','sector 11')
df['sector']=df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
df
# Out:
#                                       property_name property_type  \
# 0                      2 BHK Flat in Krishna Colony          flat
# 1                         2 BHK Flat in Ashok Vihar          flat
# 2                               2 BHK Flat in Sohna          flat
# 3                   2 BHK Flat in Sector 61 Gurgaon          flat
# 4                   2 BHK Flat in Sector 92 Gurgaon          flat
# ...                                             ...           ...
# 3949  4 Bedroom House for sale in Sector 26 Gurgaon         house
# 3950        3 Bedroom House for sale in DLF Phase 2         house
# 3951  3 Bedroom House for sale in Sector 26 Gurgaon         house
# 3952  3 Bedroom House for sale in Sector 26 Gurgaon         house
# 3953             3 Bedroom House for sale in Bissar         house
#
#                                        society           sector  price  \
# 0                       maa bhagwati residency         sector 7   0.45
# 1                                 apna enclave         sector 3   0.50
# 2                       tulsiani easy in homes  sohna road road   0.40
# 3                          smart world orchard        sector 61   1.47
# 4                             parkwood westend        sector 92   0.70
# ...                                        ...              ...    ...
# 3949                          dlf city phase 1        sector 26   5.50
# 3950                    dlf city plots phase 2        sector 25   4.25
# 3951                          dlf city phase 1        sector 26   4.50
# 3952                          dlf city phase 1        sector 26   3.25
# 3953  silverglades tarudhan valley golf resort           bissar   3.60
#
#       price_per_sqft         area                            areaWithType  \
# 0             5000.0   900.000000          Carpet area: 900 (83.61 sq.m.)
# 1             7692.0   650.026001          Carpet area: 650 (60.39 sq.m.)
# 2             6722.0   595.060994          Carpet area: 595 (55.28 sq.m.)
# 3            12250.0  1200.000000        Carpet area: 1200 (111.48 sq.m.)
# 4             5204.0  1345.119139  Super Built up area 1345(124.95 sq.m.)
# ...              ...          ...                                     ...
# 3949         30556.0  1800.000000             Plot area 200(167.23 sq.m.)
# 3950         31481.0  1350.000000             Plot area 150(125.42 sq.m.)
# 3951         33333.0  1350.000000             Plot area 150(125.42 sq.m.)
# 3952         33129.0   981.000000              Plot area 109(91.14 sq.m.)
# 3953         14815.0  2430.000000             Plot area 270(225.75 sq.m.)
#
#       bedRoom  bathroom  ...                              address floorNum  \
# 0           2         2  ...     Krishna Colony, Gurgaon, Haryana      4.0
# 1           2         2  ...   46b, Ashok Vihar, Gurgaon, Haryana      1.0
# 2           2         2  ...              Sohna, Gurgaon, Haryana     12.0
# 3           2         2  ...  Sector 61 Gurgaon, Gurgaon, Haryana      2.0
# 4           2         2  ...  Sector 92 Gurgaon, Gurgaon, Haryana      5.0
# ...       ...       ...  ...                                  ...      ...
# 3949        4         4  ...  Sector 26 Gurgaon, Gurgaon, Haryana      NaN
# 3950        3         2  ...        DLF Phase 2, Gurgaon, Haryana      NaN
# 3951        3         3  ...  Sector 26 Gurgaon, Gurgaon, Haryana      NaN
# 3952        3         3  ...  Sector 26 Gurgaon, Gurgaon, Haryana      NaN
# 3953        3         3  ...             Bissar, Gurgaon, Haryana      NaN
#
#           facing       agePossession  \
# 0           West     1 to 5 Year Old
# 1           West        10+ Year Old
# 2            NaN     0 to 1 Year Old
# 3            NaN              Dec-23
# 4            NaN  Under Construction
# ...          ...                 ...
# 3949  North-East    5 to 10 Year Old
# 3950       North        10+ Year Old
# 3951        East    5 to 10 Year Old
# 3952        West        10+ Year Old
# 3953         NaN    5 to 10 Year Old
#
#                                         nearbyLocations  \
# 0     ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1     ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2     ['Huda City Metro', 'Golf Course extn road', '...
# 3     ['Sector 55-56 Metro station', 'Bestech Centra...
# 4     ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# ...                                                 ...
# 3949  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3950  ['Sahara Mall', 'Delhi Public School', 'Privat...
# 3951  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3952  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3953                                                NaN
#
#                                             description  \
# 0     So with lift.Maa bhagwati residency is one of ...
# 1     Property situated on main road, railway statio...
# 2     This property is 15 km away from badshapur, gu...
# 3     Near to metro station of sector 56 and opposit...
# 4     We are the proud owners of this 2 bhk alongwit...
# ...                                                 ...
# 3949  Residential house, g block, dlf phase-1, gurga...
# 3950  Residential house, k block, dlf phase-2, gurga...
# 3951  Residential house, e block 150 sq.Yds , dlf ph...
# 3952  Residential house, e block, dlf phase-1, gurga...
# 3953  This 3 bhk house for sale in bissar is an idea...
#
#                                          furnishDetails  \
# 0     ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1     ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    []
# ...                                                 ...
# 3949  ['10 Light', 'No AC', 'No Bed', 'No Chimney', ...
# 3950                                                NaN
# 3951  ['6 Fan', '20 Light', 'No AC', 'No Bed', 'No C...
# 3952  ['5 Fan', '16 Light', 'No AC', 'No Bed', 'No C...
# 3953  ['1 Water Purifier', '10 Fan', '1 Fridge', '1 ...
#
#                                                features  \
# 0     ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1     ['Security / Fire Alarm', 'Maintenance Staff',...
# 2     ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3     ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                   NaN
# ...                                                 ...
# 3949  ['Feng Shui / Vaastu Compliant', 'High Ceiling...
# 3950  ['High Ceiling Height', 'Maintenance Staff', '...
# 3951  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3952  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3953  ['Centrally Air Conditioned', 'Water purifier'...
#
#                                                  rating noOfFloor
# 0     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 1     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 2     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 3                                                   NaN       NaN
# 4     ['Environment5 out of 5', 'Safety3 out of 5', ...       NaN
# ...                                                 ...       ...
# 3949                                                NaN       2.0
# 3950  ['Environment5 out of 5', 'Safety5 out of 5', ...       2.0
# 3951                                                NaN       2.0
# 3952                                                NaN       2.0
# 3953                                                NaN       2.0
#
# [3954 rows x 22 columns]

# %%
a=df['sector'].value_counts()[df['sector'].value_counts()>=3]

# %%
df=df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road road      175
# sector 102           113
# sector 85            110
# sector 92            104
# sector 69             94
#                     ...
# sector 110 a           3
# patel nagar            3
# sector 73              3
# b block sector 43      3
# sector 27              3
# Name: count, Length: 130, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\3954173571.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\3954173571.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\3954173571.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\3954173571.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\3954173571.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\3954173571.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\3954173571.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\3954173571.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\3954173571.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

# %%
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\600812590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\600812590.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\600812590.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\600812590.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\600812590.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\600812590.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\600812590.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\600812590.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df
# Out:
#                                         property_name property_type  \
# 0                        2 BHK Flat in Krishna Colony          flat
# 1                           2 BHK Flat in Ashok Vihar          flat
# 2                                 2 BHK Flat in Sohna          flat
# 3                     2 BHK Flat in Sector 61 Gurgaon          flat
# 4                     2 BHK Flat in Sector 92 Gurgaon          flat
# ...                                               ...           ...
# 3947  3 Bedroom House for sale in Sushant Lok Phase 3         house
# 3949    4 Bedroom House for sale in Sector 26 Gurgaon         house
# 3950          3 Bedroom House for sale in DLF Phase 2         house
# 3951    3 Bedroom House for sale in Sector 26 Gurgaon         house
# 3952    3 Bedroom House for sale in Sector 26 Gurgaon         house
#
#                      society           sector  price  price_per_sqft  \
# 0     maa bhagwati residency         sector 7   0.45          5000.0
# 1               apna enclave         sector 3   0.50          7692.0
# 2     tulsiani easy in homes  sohna road road   0.40          6722.0
# 3        smart world orchard        sector 61   1.47         12250.0
# 4           parkwood westend        sector 92   0.70          5204.0
# ...                      ...              ...    ...             ...
# 3947             independent        sector 57   4.75         28787.0
# 3949        dlf city phase 1        sector 26   5.50         30556.0
# 3950  dlf city plots phase 2        sector 25   4.25         31481.0
# 3951        dlf city phase 1        sector 26   4.50         33333.0
# 3952        dlf city phase 1        sector 26   3.25         33129.0
#
#              area                                       areaWithType  bedRoom  \
# 0      900.000000                     Carpet area: 900 (83.61 sq.m.)        2
# 1      650.026001                     Carpet area: 650 (60.39 sq.m.)        2
# 2      595.060994                     Carpet area: 595 (55.28 sq.m.)        2
# 3     1200.000000                   Carpet area: 1200 (111.48 sq.m.)        2
# 4     1345.119139             Super Built up area 1345(124.95 sq.m.)        2
# ...           ...                                                ...      ...
# 3947  1650.000000  Plot area 1600(148.64 sq.m.)Built Up area: 170...        3
# 3949  1800.000000                        Plot area 200(167.23 sq.m.)        4
# 3950  1350.000000                        Plot area 150(125.42 sq.m.)        3
# 3951  1350.000000                        Plot area 150(125.42 sq.m.)        3
# 3952   981.000000                         Plot area 109(91.14 sq.m.)        3
#
#       bathroom  ...                                            address  \
# 0            2  ...                   Krishna Colony, Gurgaon, Haryana
# 1            2  ...                 46b, Ashok Vihar, Gurgaon, Haryana
# 2            2  ...                            Sohna, Gurgaon, Haryana
# 3            2  ...                Sector 61 Gurgaon, Gurgaon, Haryana
# 4            2  ...                Sector 92 Gurgaon, Gurgaon, Haryana
# ...        ...  ...                                                ...
# 3947         3  ...  240 Sq.Yrd Old Siplex 3 Bhk Villa In Gated Blo...
# 3949         4  ...                Sector 26 Gurgaon, Gurgaon, Haryana
# 3950         2  ...                      DLF Phase 2, Gurgaon, Haryana
# 3951         3  ...                Sector 26 Gurgaon, Gurgaon, Haryana
# 3952         3  ...                Sector 26 Gurgaon, Gurgaon, Haryana
#
#      floorNum      facing       agePossession  \
# 0         4.0        West     1 to 5 Year Old
# 1         1.0        West        10+ Year Old
# 2        12.0         NaN     0 to 1 Year Old
# 3         2.0         NaN              Dec-23
# 4         5.0         NaN  Under Construction
# ...       ...         ...                 ...
# 3947      NaN  North-West    5 to 10 Year Old
# 3949      NaN  North-East    5 to 10 Year Old
# 3950      NaN       North        10+ Year Old
# 3951      NaN        East    5 to 10 Year Old
# 3952      NaN        West        10+ Year Old
#
#                                         nearbyLocations  \
# 0     ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1     ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2     ['Huda City Metro', 'Golf Course extn road', '...
# 3     ['Sector 55-56 Metro station', 'Bestech Centra...
# 4     ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# ...                                                 ...
# 3947  ['Radhakrishna Shani Mandir', 'Sanatan Dharm M...
# 3949  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3950  ['Sahara Mall', 'Delhi Public School', 'Privat...
# 3951  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3952  ['Dlf phase 1 metro station', 'Sikandarpur met...
#
#                                             description  \
# 0     So with lift.Maa bhagwati residency is one of ...
# 1     Property situated on main road, railway statio...
# 2     This property is 15 km away from badshapur, gu...
# 3     Near to metro station of sector 56 and opposit...
# 4     We are the proud owners of this 2 bhk alongwit...
# ...                                                 ...
# 3947  240 sq.Yrd park facing simplex 3 bhk villa for...
# 3949  Residential house, g block, dlf phase-1, gurga...
# 3950  Residential house, k block, dlf phase-2, gurga...
# 3951  Residential house, e block 150 sq.Yds , dlf ph...
# 3952  Residential house, e block, dlf phase-1, gurga...
#
#                                          furnishDetails  \
# 0     ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1     ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    []
# ...                                                 ...
# 3947  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '11 L...
# 3949  ['10 Light', 'No AC', 'No Bed', 'No Chimney', ...
# 3950                                                NaN
# 3951  ['6 Fan', '20 Light', 'No AC', 'No Bed', 'No C...
# 3952  ['5 Fan', '16 Light', 'No AC', 'No Bed', 'No C...
#
#                                                features  \
# 0     ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1     ['Security / Fire Alarm', 'Maintenance Staff',...
# 2     ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3     ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                   NaN
# ...                                                 ...
# 3947  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3949  ['Feng Shui / Vaastu Compliant', 'High Ceiling...
# 3950  ['High Ceiling Height', 'Maintenance Staff', '...
# 3951  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3952  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                                  rating noOfFloor
# 0     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 1     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 2     ['Environment4 out of 5', 'Safety4 out of 5', ...       NaN
# 3                                                   NaN       NaN
# 4     ['Environment5 out of 5', 'Safety3 out of 5', ...       NaN
# ...                                                 ...       ...
# 3947  ['Environment4 out of 5', 'Safety4 out of 5', ...       2.0
# 3949                                                NaN       2.0
# 3950  ['Environment5 out of 5', 'Safety5 out of 5', ...       2.0
# 3951                                                NaN       2.0
# 3952                                                NaN       2.0
#
# [3798 rows x 22 columns]

# %%
df.drop(columns=['property_name','address','description','rating'],inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_8276\4081953548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['property_name','address','description','rating'],inplace=True)

# %%
df
# Out:
#      property_type                 society           sector  price  \
# 0             flat  maa bhagwati residency         sector 7   0.45
# 1             flat            apna enclave         sector 3   0.50
# 2             flat  tulsiani easy in homes  sohna road road   0.40
# 3             flat     smart world orchard        sector 61   1.47
# 4             flat        parkwood westend        sector 92   0.70
# ...            ...                     ...              ...    ...
# 3947         house             independent        sector 57   4.75
# 3949         house        dlf city phase 1        sector 26   5.50
# 3950         house  dlf city plots phase 2        sector 25   4.25
# 3951         house        dlf city phase 1        sector 26   4.50
# 3952         house        dlf city phase 1        sector 26   3.25
#
#       price_per_sqft         area  \
# 0             5000.0   900.000000
# 1             7692.0   650.026001
# 2             6722.0   595.060994
# 3            12250.0  1200.000000
# 4             5204.0  1345.119139
# ...              ...          ...
# 3947         28787.0  1650.000000
# 3949         30556.0  1800.000000
# 3950         31481.0  1350.000000
# 3951         33333.0  1350.000000
# 3952         33129.0   981.000000
#
#                                            areaWithType  bedRoom  bathroom  \
# 0                        Carpet area: 900 (83.61 sq.m.)        2         2
# 1                        Carpet area: 650 (60.39 sq.m.)        2         2
# 2                        Carpet area: 595 (55.28 sq.m.)        2         2
# 3                      Carpet area: 1200 (111.48 sq.m.)        2         2
# 4                Super Built up area 1345(124.95 sq.m.)        2         2
# ...                                                 ...      ...       ...
# 3947  Plot area 1600(148.64 sq.m.)Built Up area: 170...        3         3
# 3949                        Plot area 200(167.23 sq.m.)        4         4
# 3950                        Plot area 150(125.42 sq.m.)        3         2
# 3951                        Plot area 150(125.42 sq.m.)        3         3
# 3952                         Plot area 109(91.14 sq.m.)        3         3
#
#      balcony                      additionalRoom  floorNum      facing  \
# 0          1                       not available       4.0        West
# 1          1                       not available       1.0        West
# 2          3                       not available      12.0         NaN
# 3          2                          study room       2.0         NaN
# 4          3                          study room       5.0         NaN
# ...      ...                                 ...       ...         ...
# 3947       3                          store room       NaN  North-West
# 3949       3  pooja room,study room,servant room       NaN  North-East
# 3950       3                          study room       NaN       North
# 3951       2             study room,servant room       NaN        East
# 3952       3                          study room       NaN        West
#
#            agePossession                                    nearbyLocations  \
# 0        1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1           10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2        0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
# 3                 Dec-23  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4     Under Construction  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# ...                  ...                                                ...
# 3947    5 to 10 Year Old  ['Radhakrishna Shani Mandir', 'Sanatan Dharm M...
# 3949    5 to 10 Year Old  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3950        10+ Year Old  ['Sahara Mall', 'Delhi Public School', 'Privat...
# 3951    5 to 10 Year Old  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 3952        10+ Year Old  ['Dlf phase 1 metro station', 'Sikandarpur met...
#
#                                          furnishDetails  \
# 0     ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1     ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                    []
# ...                                                 ...
# 3947  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '11 L...
# 3949  ['10 Light', 'No AC', 'No Bed', 'No Chimney', ...
# 3950                                                NaN
# 3951  ['6 Fan', '20 Light', 'No AC', 'No Bed', 'No C...
# 3952  ['5 Fan', '16 Light', 'No AC', 'No Bed', 'No C...
#
#                                                features  noOfFloor
# 0     ['Feng Shui / Vaastu Compliant', 'Security / F...        NaN
# 1     ['Security / Fire Alarm', 'Maintenance Staff',...        NaN
# 2     ['Power Back-up', 'Feng Shui / Vaastu Complian...        NaN
# 3     ['Security / Fire Alarm', 'Private Garden / Te...        NaN
# 4                                                   NaN        NaN
# ...                                                 ...        ...
# 3947  ['Feng Shui / Vaastu Compliant', 'Private Gard...        2.0
# 3949  ['Feng Shui / Vaastu Compliant', 'High Ceiling...        2.0
# 3950  ['High Ceiling Height', 'Maintenance Staff', '...        2.0
# 3951  ['Feng Shui / Vaastu Compliant', 'Private Gard...        2.0
# 3952  ['Feng Shui / Vaastu Compliant', 'Private Gard...        2.0
#
# [3798 rows x 18 columns]

# %%
df.to_csv('gurgaon_properties_cleaned.csv',index=False)
