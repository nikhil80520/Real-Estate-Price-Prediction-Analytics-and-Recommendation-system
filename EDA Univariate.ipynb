# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\asus\OneDrive\Desktop\dataset\gurgaon_properties_cleaned_v2.csv")

# %%
df
# Out:
#      property_type                 society           sector  price  \
# 0             flat  maa bhagwati residency         sector 7   0.45
# 1             flat            apna enclave         sector 3   0.50
# 2             flat  tulsiani easy in homes  sohna road road   0.40
# 3             flat     smart world orchard        sector 61   1.47
# 4             flat        parkwood westend        sector 92   0.70
# ...            ...                     ...              ...    ...
# 3793         house             independent        sector 57   4.75
# 3794         house        dlf city phase 1        sector 26   5.50
# 3795         house  dlf city plots phase 2        sector 25   4.25
# 3796         house        dlf city phase 1        sector 26   4.50
# 3797         house        dlf city phase 1        sector 26   3.25
#
#       price_per_sqft         area  \
# 0             5000.0   900.000000
# 1             7692.0   650.026001
# 2             6722.0   595.060994
# ...

# %%
df.shape
# Out:
# (3798, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3798 entries, 0 to 3797
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3798 non-null   object
#  1   society              3797 non-null   object
#  2   sector               3798 non-null   object
#  3   price                3798 non-null   float64
#  4   price_per_sqft       3798 non-null   float64
#  5   area                 3798 non-null   float64
#  6   areaWithType         3798 non-null   object
#  7   bedRoom              3798 non-null   int64
#  8   bathroom             3798 non-null   int64
#  9   balcony              3798 non-null   object
#  10  floorNum             2937 non-null   float64
#  11  facing               2698 non-null   object
#  12  agePossession        3798 non-null   object
#  13  noOfFloor            838 non-null    float64
#  14  super_built_up_area  1915 non-null   float64
# ...

# %%
df.duplicated().sum()
# Out:
# 138

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      property_type                 society           sector  price  \
# 0             flat  maa bhagwati residency         sector 7   0.45
# 1             flat            apna enclave         sector 3   0.50
# 2             flat  tulsiani easy in homes  sohna road road   0.40
# 3             flat     smart world orchard        sector 61   1.47
# 4             flat        parkwood westend        sector 92   0.70
# ...            ...                     ...              ...    ...
# 3793         house             independent        sector 57   4.75
# 3794         house        dlf city phase 1        sector 26   5.50
# 3795         house  dlf city plots phase 2        sector 25   4.25
# 3796         house        dlf city phase 1        sector 26   4.50
# 3797         house        dlf city phase 1        sector 26   3.25
#
#       price_per_sqft         area  \
# 0             5000.0   900.000000
# 1             7692.0   650.026001
# 2             6722.0   595.060994
# ...

# %% [markdown]
# # Property_type

# %%
df['property_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='property_type'>

# %% [raw]
# Observations
# 1-Flats are in majority(75 percent) and there are less number of houses(25 percent)
# 2-No missing values

# %% [markdown]
# # Society

# %%
df['society'].value_counts().shape
# Out:
# (674,)

# %%
df['society'].value_counts(normalize=True).cumsum().head(75)
# Out:
# society
# independent                             0.131457
# tulip violet                            0.151954
# ss the leaf                             0.171905
# dlf new town heights                    0.183383
# shapoorji pallonji joyville gurugram    0.194862
#                                           ...
# umang monsoon breeze                    0.553976
# ramsons kshitij                         0.557529
# the close north                         0.561082
# ats kocoon                              0.564635
# mvn athens                              0.567915
# Name: proportion, Length: 75, dtype: float64

# %%
society_counts=df['society'].value_counts()

# %%
frequency_bins={
   'very high(>100)':(society_counts>100).sum(),
    'high (50-100)':((society_counts>=50)&(society_counts<=100)).sum(),
    'Average (10-49)':((society_counts>=10)&(society_counts<50)).sum(),
    'low (2-9)':((society_counts>=2)&(society_counts<10)).sum(),
    'Very Low(1)':(society_counts==1).sum()
}

# %%
frequency_bins
# Out:
# {'very high(>100)': 1,
#  'high (50-100)': 2,
#  'Average (10-49)': 92,
#  'low (2-9)': 272,
#  'Very Low(1)': 307}

# %%
df['society'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='society'>

# %%
df['society'].value_counts().head(1)/df['society'].value_counts().sum()*100
# Out:
# society
# independent    13.145668
# Name: count, dtype: float64

# %%
df[df['society'].isnull()]
# Out:
#      property_type society     sector  price  price_per_sqft         area  \
# 2710          flat     NaN  sector 78    0.6          3692.0  1625.135428
#
#                             areaWithType  bedRoom  bathroom balcony  ...  \
# 2710  Built Up area: 1625 (150.97 sq.m.)        2         2       0  ...
#
#       super_built_up_area built_up_area carpet_area  study room  servant room  \
# 2710                  NaN        1625.0         NaN           0             0
#
#       store room  pooja room  others  furnishing_type  luxury_score
# 2710           0           0       0                0             0
#
# [1 rows x 24 columns]

# %% [raw]
# Observations
# 1-Around 13% properties are independent tag.
# 2-There are 674 societies.
# 3-There are 75 percent of the properties and the rest 50 percent of the properties come under the remaining 600 societies
#   -Very High (>100) only 1 society has more than 100 listings.
#   -High (50-100) 2 societies have between 50 to 100 listings.
#   -Average (10-49) 92 societies have 10 to 49 listings.
#   -Low (2-10) 272 societies have 2 to 10 listings.
#   -Very Low (1) 307 societies has only 1 listings.

# %% [markdown]
# # Sector

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road road    166
# sector 85          108
# sector 102         107
# sector 92           99
# sector 69           93
#                   ...
# sector 17a           3
# sector 88b           3
# sector 17b           3
# sector 73            3
# sector 27            3
# Name: count, Length: 115, dtype: int64

# %%
df['sector'].value_counts().shape
# Out:
# (115,)

# %%
df['sector'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='sector'>

# %%
sector_counts=df['sector'].value_counts()
sector_frequency_bins={
   'very high(>100)':(sector_counts>100).sum(),
    'high (50-100)':((sector_counts>=50)&(sector_counts<=100)).sum(),
    'Average (10-49)':((sector_counts>=10)&(sector_counts<50)).sum(),
    'low (2-9)':((sector_counts>=2)&(sector_counts<10)).sum(),
    'Very Low(1)':(sector_counts==1).sum()
}

# %%
sector_frequency_bins
# Out:
# {'very high(>100)': 3,
#  'high (50-100)': 24,
#  'Average (10-49)': 62,
#  'low (2-9)': 26,
#  'Very Low(1)': 0}

# %% [raw]
# Observations
# 1-ThFrequency distribution of sector.
# 3-There are 75 percent of the properties and the rest 50 percent of the properties come under the remaining 600 societies
#   -Very High (>100) 3 sectors has more than 100 listings.
#   -High (50-100) 24 sectors have between 50 to 100 listings.
#   -Average (10-49) 62 sectors have 10 to 49 listings.
#   -Low (2-10) 26 sectors have 2 to 10 listings.
#   -Very Low (1) 0 sector has only 1 listings.

# %% [markdown]
# # Price

# %%
df['price'].shape
# Out:
# (3660,)

# %%
df['price'].isnull().sum()
# Out:
# 0

# %%
df['price'].duplicated().sum()
# Out:
# 3187

# %%
df['price'].describe()
# Out:
# count    3660.000000
# mean        2.533664
# std         2.980623
# min         0.070000
# 25%         0.950000
# 50%         1.520000
# 75%         2.750000
# max        31.500000
# Name: price, dtype: float64

# %%
sns.histplot(df['price'],kde=True,bins=50)
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(x=df['price'],color='red')
# Out:
# <Axes: xlabel='price'>

# %% [raw]
# Descriptive Statistics:
#     -count:There are 3660 non-missing value
#     -Mean Price:The average price is approx. 2.53 crores.
#     -Median:The median (or 50th percentile) price is 1.52 crores.
#     -S.D.:The prices have a S.D. of 2.98 indicating variability in the prices
#     -Range:Prices range from minimum of 0.07 crores to maximum of 31.5 crores.
#     -IQR:Thewe interquartile range is from 0.95   to 2.75 crores.
# Visualizations:
#     -Distribution: The histogram indicates that most properties are priced in the lower range (below 5 crores),with a few properties going beyond 10 crores.
#     -box plot:The box plot shows the spread of the data and potential outliers .Properties priced above approx. 10 crores might be considered outlieers as they lie beyond the upper whisker of the boxplot.
# Missing values:There are 0 missing values the prices columns

# %%
skewness=df['price'].skew()
kurtosis=df['price'].kurt()

# %%
print(skewness,kurtosis)
# Out:
# 3.2791704733134623 14.933372629214258

# %% [raw]
# SKewness:It indicates the positive skew.The means that the distribution tail skewed to right aligns with our observation from the histogram where most properites have prices on the lower end a few high -priced properties
# Kurtosis:The kurtosis value is approx. 14.93. The kurt higher than 3 indicates a distribution with heavier talls and more outliers compared to normal distibution

# %%
quartiles=df['price'].quantile([0.01,0.05,0.95,0.99])

# %%
quartiles
# Out:
# 0.01     0.250
# 0.05     0.370
# 0.95     8.500
# 0.99    15.264
# Name: price, dtype: float64

# %% [raw]
# Quartile Analysis:
#     1% Quartile:Only 1% of properties are priced below 0.25 crores.
#     5% Quartile:5% of properties are priced below 0.37 crores.
#     95% Quartile:95% of properties are priced below 8.5 coroes.
#     99% Quartile:99% of properties are priced below 15.26 crores.15.26 crores,indicating that very few peoperties are priced above this value.

# %%
q1=df['price'].describe()['25%']

# %%
q3=df['price'].describe()['75%']

# %%
IQR=q3-q1

# %%
lower_bound=q1-1.5*IQR
upper_bound=q3+1.5*IQR

# %%
print(upper_bound,lower_bound)
# Out:
# 5.45 -1.7500000000000002

# %%
outliers=df[(df['price']<lower_bound)|(df['price']>upper_bound)]

# %%
outliers.shape
# Out:
# (425, 24)

# %%
outliers['price'].describe()
# Out:
# count    425.000000
# mean       9.235624
# std        4.065259
# min        5.460000
# 25%        6.460000
# 50%        8.000000
# 75%       10.750000
# max       31.500000
# Name: price, dtype: float64

# %% [raw]
# Outliers Analysis(using IQR method)
# -based on the IQR method,there are 425 properties considered as outliers
# -These outliers have an average price of approximately 9.24 crores.
# -The ranges for these outliers is from 5.46 crores to 31.5 crores

# %%
bins=[0,1,2,3,5,10,20,50]

bins_labels=['0-1','1-2','2-3','3-5','5-10','10-20','20-50']

# %%
pd.cut(df['price'],bins=bins,labels=bins_labels,right=False).value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='price'>

# %% [raw]
# -The majority of properties are priced in the '1-2 crores'and '2-3 crores'ranges.
# -There's a significant drop in the number of properties priced above '5 crores'.

# %%
ecdf=df['price'].value_counts().sort_index().cumsum()/len(df['price'])

# %%
plt.plot(ecdf.index,ecdf,marker='.',linestyle='none')
plt.grid()

# %%
plt.plot(figsize=(15,6))

plt.subplot(1,2,1)
sns.histplot(df['price'],kde=True,bins=50,color='skyblue')
plt.title('Distribution of rpices (originals)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')


plt.subplot(1,2,2)
sns.histplot(np.log1p(df['price']),kde=True,bins=50,color='lightgreen')
plt.title('Distribution of rpices (originals)')
plt.xlabel('log(Price (in Crores))')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_20196\1993318264.py:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
skewness=np.log1p(df['price']).skew()

# %%
kurtosis=np.log1p(df['price']).kurt()

# %%
print(kurtosis,skewness)
# Out:
# 0.9646692415449296 1.0740709565255315

# %%
plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
sns.boxplot(x=df['price'], color='skyblue')
plt.title('Distribution of prices (original)')
plt.xlabel('Price (in crores)')
plt.ylabel('Frequency')

plt.subplot(1,2,2)  # Corrected index here
sns.boxplot(x=np.log1p(df['price']), color='lightgreen')
plt.title('Distribution of prices (Log Transformed)')
plt.xlabel('log(Price (in crores))')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Price_per_sqft

# %%
df['price_per_sqft'].isnull().sum()
# Out:
# 0

# %%
df['price_per_sqft'].describe()
# Out:
# count      3660.000000
# mean      13892.668306
# std       23210.067190
# min           4.000000
# 25%        6817.250000
# 50%        9020.000000
# 75%       13880.500000
# max      600000.000000
# Name: price_per_sqft, dtype: float64

# %%
sns.histplot(df['price_per_sqft'],kde=True,bins=50)
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
sns.boxplot(df['price_per_sqft'],color='lightgreen')
# Out:
# <Axes: >

# %%
skewness=df['price_per_sqft'].skew()
kurtosis=df['price_per_sqft'].kurt()

# %%
print(skewness,kurtosis)
# Out:
# 11.437190426237102 186.9280132353288

# %%
quartiles=df['price'].quantile([0.01,0.05,0.95,0.99])

# %%
quartiles
# Out:
# 0.01     0.250
# 0.05     0.370
# 0.95     8.500
# 0.99    15.264
# Name: price, dtype: float64

# %%
plt.plot(figsize=(15,6))

plt.subplot(1,2,1)
sns.histplot(df['price_per_sqft'],kde=True,bins=50,color='skyblue')
plt.title('Distribution of prices (originals)')
plt.xlabel('Price ')
plt.ylabel('Frequency')


plt.subplot(1,2,2)
sns.histplot(np.log1p(df['price_per_sqft']),kde=True,bins=50,color='lightgreen')
plt.title('Distribution of prices (originals)')
plt.xlabel('log(Price )')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_20196\3081560919.py:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Bedroom

# %%
df['bedRoom'].isnull().sum()
# Out:
# 0

# %%
df['bedRoom'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# # Bathroom

# %%
df['bathroom'].isnull().sum()
# Out:
# 0

# %%
df['bathroom'].value_counts().head(10).sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='bathroom'>

# %%
df['bathroom'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# # Balcony

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['balcony'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='balcony'>

# %%
df['balcony'].value_counts(normalize=True).head().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
df.iloc[:,10:]
# Out:
#       floorNum      facing       agePossession  noOfFloor  \
# 0          4.0        West      Relatively New        NaN
# 1          1.0        West        Old Property        NaN
# 2         12.0         NaN        New Property        NaN
# 3          2.0         NaN           Undefined        NaN
# 4          5.0         NaN  Under Construction        NaN
# ...        ...         ...                 ...        ...
# 3793       NaN  North-West      Moderately Old        2.0
# 3794       NaN  North-East      Moderately Old        2.0
# 3795       NaN       North        Old Property        2.0
# 3796       NaN        East      Moderately Old        2.0
# 3797       NaN        West        Old Property        2.0
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 0                     NaN            NaN        900.0           0
# 1                     NaN            NaN        650.0           0
# 2                     NaN            NaN        595.0           0
# ...

# %% [markdown]
# # Floor Number

# %%
df['floorNum'].isnull().sum()
# Out:
# 848

# %%
df['floorNum'].describe()
# Out:
# count    2812.000000
# mean        8.005334
# std         6.196616
# min         0.000000
# 25%         3.000000
# 50%         7.000000
# 75%        11.000000
# max        45.000000
# Name: floorNum, dtype: float64

# %%
df['floorNum'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='floorNum'>

# %%
sns.boxplot(df['floorNum'],color='lightgreen')
# Out:
# <Axes: >

# %% [raw]
# -The mojority of the properties lie between the ground floor (0) and 25th floor.
# -Floors 1 to 4 are particularily common,with the 2rd floor being the most frequent.
# -There are a few properties located at higher floors, but their frequency is much lower.
# -The box plot reveals that the majority of the properties are concentrated the lower floor.The interquartile range lies between 2nd and 11th floor
# -Data points beyond the 'Whiskers' of the box plot ,especially on the higher side,indicate potential outliers.

# %% [markdown]
# # Facing

# %%
df['facing'].isnull().sum()
# Out:
# 1039

# %%
df['facing'].value_counts()
# Out:
# facing
# North-East    621
# East          620
# North         386
# West          247
# South         231
# North-West    192
# South-East    171
# South-West    153
# Name: count, dtype: int64

# %%
df['facing'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='facing'>

# %% [markdown]
# # AgePossesion

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1640
# New Property           590
# Moderately Old         558
# Undefined              437
# Old Property           302
# Under Construction     133
# Name: count, dtype: int64

# %%
df['agePossession'].isnull().sum()
# Out:
# 0

# %%
df['agePossession'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='agePossession'>

# %% [markdown]
# # Areas

# %%
df['super_built_up_area'].isnull().sum()
# Out:
# 1785

# %%
sns.histplot(df['super_built_up_area'],kde=True)
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='super_built_up_area', ylabel='Count'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
sns.boxplot(df['super_built_up_area'],color='lightgreen')
# Out:
# <Axes: >

# %% [raw]
# -Most properties have a super built up area between approx. 1000 sqft and 2500 sqft
# -There are a few properties with a significantly larger area,leading to a right skewed distribution.
# -The interquartile range (IQR) lies between roughly 1480 sqft indicating that the middle 50% of the properties ffall within this range.
# -There are several data beyond the upper 'whisker' of the box plot ,indicating potential outliers.These are properties with an unusally large super built up area.

# %%
df['built_up_area'].isnull().sum()
# Out:
# 1986

# %%
df['built_up_area'].describe()
# Out:
# count      1674.000000
# mean       2386.198937
# std       18026.926801
# min           2.000000
# 25%        1110.500000
# 50%        1650.000000
# 75%        2400.000000
# max      737147.000000
# Name: built_up_area, dtype: float64

# %%
sns.histplot(df['built_up_area'].dropna(),bins=50,kde=False)
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='built_up_area', ylabel='Count'>

# %%
sns.boxplot(df['built_up_area'],color='lightgreen')
# Out:
# <Axes: >

# %% [markdown]
# # Additional rooms

# %%
plt.figure(figsize=(20, 12))

for idx, room in enumerate(['study room', 'servant room', 'store room', 'pooja room', 'others'], 1):
    ax = plt.subplot(2, 3, idx)
    df[room].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, ax=ax)
    plt.title(f'Distribution of {room.title()}')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Furnishing type

# %%
df['furnishing_type'].isnull().sum()
# Out:
# 0

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 0    2426
# 2    1033
# 1     201
# Name: count, dtype: int64

# %% [markdown]
# # Luxury Score

# %%
df['luxury_score'].isnull().sum()
# Out:
# 0

# %%
df['luxury_score'].describe()
# Out:
# count    3660.000000
# mean       71.535519
# std        53.067275
# min         0.000000
# 25%        31.000000
# 50%        59.000000
# 75%       110.000000
# max       174.000000
# Name: luxury_score, dtype: float64

# %%
sns.histplot(df['luxury_score'],bins=50,color='skyblue',kde=True)
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='luxury_score', ylabel='Count'>

# %%
sns.boxplot(df['luxury_score'],color='lightgreen')
# Out:
# <Axes: >
