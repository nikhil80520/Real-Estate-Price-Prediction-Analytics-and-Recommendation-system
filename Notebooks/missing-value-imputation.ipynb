# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv(r"C:\Users\asus\OneDrive\Desktop\dataset\gurgaon_properties_outliers_treated.csv")

# %%
df.head()
# Out:
#   property_type                 society           sector  price  \
# 0          flat  maa bhagwati residency         sector 7   0.45
# 1          flat            apna enclave         sector 3   0.50
# 2          flat  tulsiani easy in homes  sohna road road   0.40
# 3          flat     smart world orchard        sector 61   1.47
# 4          flat        parkwood westend        sector 92   0.70
#
#    price_per_sqft         area                            areaWithType  \
# 0          5000.0   900.000000          Carpet area: 900 (83.61 sq.m.)
# 1          7692.0   650.026001          Carpet area: 650 (60.39 sq.m.)
# 2          6722.0   595.060994          Carpet area: 595 (55.28 sq.m.)
# 3         12250.0  1200.000000        Carpet area: 1200 (111.48 sq.m.)
# 4          5204.0  1345.119139  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum facing       agePossession  noOfFloor  \
# 0        2         2       1       4.0   West      Relatively New        NaN
# 1        2         2       1       1.0   West        Old Property        NaN
# 2        2         2       3      12.0    NaN        New Property        NaN
# 3        2         2       2       2.0    NaN           Undefined        NaN
# 4        2         2       3       5.0    NaN  Under Construction        NaN
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN        900.0           0             0
# 1                  NaN            NaN        650.0           0             0
# 2                  NaN            NaN        595.0           0             0
# 3                  NaN            NaN       1200.0           1             0
# 4               1345.0            NaN          NaN           1             0
#
#    store room  pooja room  others  furnishing_type  luxury_score  \
# 0           0           0       0                0            28
# 1           0           0       0                2            37
# 2           0           0       0                0            36
# 3           0           0       0                0            76
# 4           0           0       0                0             0
#
#    area_room_ratio
# 0       450.000000
# 1       325.013001
# 2       297.530497
# 3       600.000000
# 4       672.559570

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                695
# facing                  992
# agePossession             0
# noOfFloor              2820
# super_built_up_area    1621
# built_up_area          1966
# carpet_area            1662
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %% [markdown]
# ### Built up area

# %%
sns.scatterplot(data=df,x='built_up_area',y='super_built_up_area')
# Out:
# <Axes: xlabel='built_up_area', ylabel='super_built_up_area'>

# %%
sns.scatterplot(data=df,x='built_up_area',y='carpet_area')
# Out:
# <Axes: xlabel='built_up_area', ylabel='carpet_area'>

# %%
((df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull()))
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3490    False
# 3491    False
# 3492    False
# 3493    False
# 3494    False
# Length: 3495, dtype: bool

# %%
all_present_df = df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))]

# %%
all_present_df.shape
# Out:
# (531, 25)

# %%
super_to_built_up_ratio = (all_present_df['super_built_up_area']/all_present_df['built_up_area']).median()

# %%
carpet_to_built_up_ratio = (all_present_df['carpet_area']/all_present_df['built_up_area']).median()

# %%
print(super_to_built_up_ratio, carpet_to_built_up_ratio)
# Out:
# 1.105263157894737 0.9

# %%
# both present built up null
sbc_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
sbc_df.head()
# Out:
#    property_type                 society           sector  price  \
# 30          flat             bhawna cghs        sector 43   3.25
# 35          flat       chintels paradiso       sector 109   1.80
# 36          flat  breez global hill view  sohna road road   0.30
# 57          flat  silverglades the melia  sohna road road   1.01
# 59          flat      umang winter hills        sector 77   0.99
#
#     price_per_sqft         area  \
# 30         10156.0  3200.078771
# 35          8866.0  2030.227837
# 36          5403.0   555.247085
# 57          7000.0  1442.857143
# 59          7857.0  1260.022910
#
#                                          areaWithType  bedRoom  bathroom  \
# 30  Super Built up area 3200(297.29 sq.m.)Carpet a...        4         4
# 35  Super Built up area 2030(188.59 sq.m.)Carpet a...        3         3
# 36  Super Built up area 655(60.85 sq.m.)Carpet are...        2         2
# 57  Super Built up area 1450(134.71 sq.m.)Carpet a...        2         2
# 59  Super Built up area 1260(117.06 sq.m.)Carpet a...        2         2
#
#    balcony  floorNum      facing   agePossession  noOfFloor  \
# 30      3+      12.0         NaN  Moderately Old        NaN
# 35       2       0.0        East  Moderately Old        NaN
# 36       2       6.0  North-East    New Property        NaN
# 57       3      12.0         NaN       Undefined        NaN
# 59       2       1.0       North  Relatively New        NaN
#
#     super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 30               3200.0            NaN       3000.0           0             0
# 35               2030.0            NaN       1785.0           0             1
# 36                655.0            NaN        555.0           0             0
# 57               1450.0            NaN        950.0           1             0
# 59               1260.0            NaN       1000.0           0             0
#
#     store room  pooja room  others  furnishing_type  luxury_score  \
# 30           0           1       0                2           119
# 35           0           0       0                0            83
# 36           0           0       0                0           109
# 57           0           0       0                0            80
# 59           0           0       0                0            97
#
#     area_room_ratio
# 30       800.019693
# 35       676.742612
# 36       277.623542
# 57       721.428571
# 59       630.011455

# %%
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_11940\1215074969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)

# %%
df.update(sbc_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                695
# facing                  992
# agePossession             0
# noOfFloor              2820
# super_built_up_area    1621
# built_up_area          1545
# carpet_area            1662
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# sb present c is null built up null
sb_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())]

# %%
sb_df.head()
# Out:
#    property_type                     society             sector  price  \
# 4           flat            parkwood westend          sector 92   0.70
# 6           flat                  the cocoon  dwarka expressway   2.00
# 13          flat                      godrej          sector 33   0.95
# 14          flat        shree vardhman flora          sector 90   0.70
# 18          flat  central park flower valley     sector 33 road   2.20
#
#     price_per_sqft         area                            areaWithType  \
# 4           5204.0  1345.119139  Super Built up area 1345(124.95 sq.m.)
# 6          13333.0  1500.037501  Super Built up area 1500(139.35 sq.m.)
# 13          6859.0  1385.041551  Super Built up area 1385(128.67 sq.m.)
# 14          5384.0  1300.148588  Super Built up area 1300(120.77 sq.m.)
# 18         10476.0  2100.038183   Super Built up area 2100(195.1 sq.m.)
#
#     bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 4         2         2       3       5.0         NaN  Under Construction
# 6         3         3       3       5.0         NaN        New Property
# 13        2         2      3+       3.0  South-East  Under Construction
# 14        2         2       3      13.0         NaN        New Property
# 18        3         3       3      12.0  North-East        New Property
#
#     noOfFloor  super_built_up_area  built_up_area  carpet_area  study room  \
# 4         NaN               1345.0            NaN          NaN           1
# 6         NaN               1500.0            NaN          NaN           0
# 13        NaN               1385.0            NaN          NaN           0
# 14        NaN               1300.0            NaN          NaN           1
# 18        NaN               2100.0            NaN          NaN           0
#
#     servant room  store room  pooja room  others  furnishing_type  \
# 4              0           0           0       0                0
# 6              0           0           0       0                0
# 13             0           0           0       0                0
# 14             0           0           0       0                0
# 18             1           0           0       0                2
#
#     luxury_score  area_room_ratio
# 4              0       672.559570
# 6              0       500.012500
# 13             0       692.520776
# 14            15       650.074294
# 18            49       700.012728

# %%
sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_11940\1714170073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)

# %%
df.update(sb_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                695
# facing                  992
# agePossession             0
# noOfFloor              2820
# super_built_up_area    1621
# built_up_area           671
# carpet_area            1662
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# sb null c is present built up null
c_df = df[(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
c_df.head()
# Out:
#   property_type                 society           sector  price  \
# 0          flat  maa bhagwati residency         sector 7   0.45
# 1          flat            apna enclave         sector 3   0.50
# 2          flat  tulsiani easy in homes  sohna road road   0.40
# 3          flat     smart world orchard        sector 61   1.47
# 7          flat             ats triumph       sector 104   1.80
#
#    price_per_sqft         area                      areaWithType  bedRoom  \
# 0          5000.0   900.000000    Carpet area: 900 (83.61 sq.m.)        2
# 1          7692.0   650.026001    Carpet area: 650 (60.39 sq.m.)        2
# 2          6722.0   595.060994    Carpet area: 595 (55.28 sq.m.)        2
# 3         12250.0  1200.000000  Carpet area: 1200 (111.48 sq.m.)        2
# 7          7860.0  2290.076336  Carpet area: 2290 (212.75 sq.m.)        3
#
#    bathroom balcony  floorNum facing   agePossession  noOfFloor  \
# 0         2       1       4.0   West  Relatively New        NaN
# 1         2       1       1.0   West    Old Property        NaN
# 2         2       3      12.0    NaN    New Property        NaN
# 3         2       2       2.0    NaN       Undefined        NaN
# 7         4       3      14.0    NaN    New Property        NaN
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN        900.0           0             0
# 1                  NaN            NaN        650.0           0             0
# 2                  NaN            NaN        595.0           0             0
# 3                  NaN            NaN       1200.0           1             0
# 7                  NaN            NaN       2290.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score  \
# 0           0           0       0                0            28
# 1           0           0       0                2            37
# 2           0           0       0                0            36
# 3           0           0       0                0            76
# 7           0           0       0                0            60
#
#    area_room_ratio
# 0       450.000000
# 1       325.013001
# 2       297.530497
# 3       600.000000
# 7       763.358779

# %%
c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_11940\2136919732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)

# %%
df.update(c_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                695
# facing                  992
# agePossession             0
# noOfFloor              2820
# super_built_up_area    1621
# built_up_area             0
# carpet_area            1662
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
sns.scatterplot(data=df,x='built_up_area',y='price')
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
anamoly_df = df[(df['built_up_area'] < 2000) & (df['price'] > 2.5)][['price','area','built_up_area']]

# %%
anamoly_df.sample(5)
# Out:
#       price    area  built_up_area
# 3393   4.25  1350.0          161.0
# 3467   4.45  1265.0          150.0
# 2836   5.75  1935.0         1935.0
# 3372  25.00  8036.0         1000.0
# 2853   8.80  2115.0          267.0

# %%
anamoly_df['built_up_area'] = anamoly_df['area']

# %%
df.update(anamoly_df)

# %%
sns.scatterplot(data=df,x='built_up_area',y='price')
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
# Assuming df is your DataFrame
df = df[df['built_up_area'] < 20000]

# %%
sns.scatterplot(data=df,x='built_up_area',y='price')
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area','area_room_ratio'],inplace=True)

# %%
df.head()
# Out:
#   property_type                 society           sector  price  \
# 0          flat  maa bhagwati residency         sector 7   0.45
# 1          flat            apna enclave         sector 3   0.50
# 2          flat  tulsiani easy in homes  sohna road road   0.40
# 3          flat     smart world orchard        sector 61   1.47
# 4          flat        parkwood westend        sector 92   0.70
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum facing  \
# 0          5000.0        2         2       1       4.0   West
# 1          7692.0        2         2       1       1.0   West
# 2          6722.0        2         2       3      12.0    NaN
# 3         12250.0        2         2       2       2.0    NaN
# 4          5204.0        2         2       3       5.0    NaN
#
#         agePossession  noOfFloor  built_up_area  study room  servant room  \
# 0      Relatively New        NaN         1000.0           0             0
# 1        Old Property        NaN          722.0           0             0
# 2        New Property        NaN          661.0           0             0
# 3           Undefined        NaN         1333.0           1             0
# 4  Under Construction        NaN         1217.0           1             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            28
# 1           0           0       0                2            37
# 2           0           0       0                0            36
# 3           0           0       0                0            76
# 4           0           0       0                0             0

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum            695
# facing              992
# agePossession         0
# noOfFloor          2818
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %% [markdown]
# ### floorNum

# %%
df[df['floorNum'].isnull()]
# Out:
#      property_type                                     society  \
# 169           flat                          experion heartsong
# 199           flat  ganpati apartment  2, laxman vihar phase 1
# 2023          flat                  huda housing board society
# 2573          flat                                         NaN
# 2721          flat                                apna enclave
# ...            ...                                         ...
# 3490         house                                 independent
# 3491         house                            dlf city phase 1
# 3492         house                      dlf city plots phase 2
# 3493         house                            dlf city phase 1
# 3494         house                            dlf city phase 1
#
#                  sector  price  price_per_sqft  bedRoom  bathroom balcony  \
# 169   dwarka expressway   1.08          6150.0        3         3       0
# 199            sector 4   0.45          4705.0        2         2       1
# 2023          sector 52   0.45          9745.0        1         1       0
# 2573          sector 78   0.60          3692.0        2         2       0
# 2721           sector 3   0.80          6153.0        3         3       1
# ...                 ...    ...             ...      ...       ...     ...
# 3490          sector 57   4.75         28788.0        3         3       3
# 3491          sector 26   5.50         30556.0        4         4       3
# 3492          sector 25   4.25         31481.0        3         2       3
# 3493          sector 26   4.50         33333.0        3         3       2
# 3494          sector 26   3.25          3681.0        3         3       3
#
#       floorNum      facing       agePossession  noOfFloor  built_up_area  \
# 169        NaN         NaN  Under Construction        NaN         1758.0
# 199        NaN        East      Relatively New        NaN          944.0
# 2023       NaN  North-West      Moderately Old        NaN          513.0
# 2573       NaN         NaN  Under Construction        NaN         1625.0
# 2721       NaN         NaN        Old Property        NaN         1000.0
# ...        ...         ...                 ...        ...            ...
# 3490       NaN  North-West      Moderately Old        2.0         1650.0
# 3491       NaN  North-East      Moderately Old        2.0         1800.0
# 3492       NaN       North        Old Property        2.0         1350.0
# 3493       NaN        East      Moderately Old        2.0         1350.0
# 3494       NaN        West        Old Property        2.0         8829.0
#
#       study room  servant room  store room  pooja room  others  \
# 169            0             0           0           0       0
# 199            0             0           0           0       0
# 2023           0             0           0           1       0
# 2573           0             0           0           0       0
# 2721           0             0           0           0       0
# ...          ...           ...         ...         ...     ...
# 3490           0             0           1           0       0
# 3491           1             1           0           1       0
# 3492           1             0           0           0       0
# 3493           1             1           0           0       0
# 3494           1             0           0           0       0
#
#       furnishing_type  luxury_score
# 169                 0             0
# 199                 0            46
# 2023                2            43
# 2573                0             0
# 2721                0             0
# ...               ...           ...
# 3490                2            96
# 3491                0            69
# 3492                0            35
# 3493                0            70
# 3494                0            79
#
# [695 rows x 20 columns]

# %%
df[df['property_type'] == 'house']['floorNum']
# Out:
# 2805   NaN
# 2806   NaN
# 2807   NaN
# 2808   NaN
# 2809   NaN
#         ..
# 3490   NaN
# 3491   NaN
# 3492   NaN
# 3493   NaN
# 3494   NaN
# Name: floorNum, Length: 690, dtype: float64

# %%
df['floorNum'].fillna(2.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum              0
# facing              992
# agePossession         0
# noOfFloor          2818
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %%
1011/df.shape[0]
# Out:
# 0.28943601488691667

# %% [markdown]
# ### facing

# %%
df['facing'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.drop(columns=['facing','noOfFloor'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                           society      sector  price  \
# 1249          flat  emaar mgf emerald floors premier   sector 65   2.40
# 1096          flat                      tulip violet   sector 69   1.38
# 324           flat                  dlf the skycourt   sector 86   1.54
# 223           flat            emaar imperial gardens  sector 102   2.05
# 1738          flat              dlf new town heights   sector 90   1.88
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 1249         14545.0        3         3       3       3.0  Relatively New
# 1096          8966.0        3         3       1      12.0  Relatively New
# 324           9221.0        3         3      3+      15.0  Relatively New
# 223           9876.0        3         4      3+      14.0  Relatively New
# 1738          6894.0        4         4      3+      20.0  Relatively New
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 1249         1600.0           1             1           0           0       0
# 1096         1392.0           0             0           0           1       0
# 324          1780.0           0             1           0           0       0
# 223          2250.0           0             1           0           0       0
# 1738         2726.0           0             1           0           1       0
#
#       furnishing_type  luxury_score
# 1249                2            49
# 1096                0            86
# 324                 0           174
# 223                 0           116
# 1738                0           145

# %%
df[df['society'].isnull()]
# Out:
#      property_type society     sector  price  price_per_sqft  bedRoom  \
# 2573          flat     NaN  sector 78    0.6          3692.0        2
#
#       bathroom balcony  floorNum       agePossession  built_up_area  \
# 2573         2       0       2.0  Under Construction         1625.0
#
#       study room  servant room  store room  pooja room  others  \
# 2573           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 2573                0             0

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.drop(index=[2573],inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %% [markdown]
# ### agePossession

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1590
# New Property           552
# Moderately Old         521
# Undefined              419
# Old Property           278
# Under Construction     131
# Name: count, dtype: int64

# %%
df[df['agePossession'] == 'Undefined']
# Out:
#      property_type                         society      sector  price  \
# 3             flat             smart world orchard   sector 61   1.47
# 5             flat  signature global infinity mall   sector 36   0.41
# 9             flat                  raheja revanta   sector 78   4.75
# 10            flat        signature global city 81   sector 81   0.96
# 15            flat                      sobha city  sector 108   3.95
# ...            ...                             ...         ...    ...
# 3156         house                     independent  sector 108   1.34
# 3158         house                     independent   sector 39   0.34
# 3159         house                     independent  sector 105   9.90
# 3160         house                     independent   sector 43   2.15
# 3162         house         project mianwali colony   sector 12   2.00
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum agePossession  \
# 3            12250.0        2         2       2       2.0     Undefined
# 5             6269.0        2         2       3       3.0     Undefined
# 9            16885.0        3         3       2      31.0     Undefined
# 10            9767.0        2         2       2       1.0     Undefined
# 15           16859.0        4         5       3      25.0     Undefined
# ...              ...      ...       ...     ...       ...           ...
# 3156          5000.0        1         1       0       2.0     Undefined
# 3158          7556.0        1         1       1       2.0     Undefined
# 3159         49500.0        2         2       2       2.0     Undefined
# 3160         13030.0        1         1       0       2.0     Undefined
# 3162         14815.0        5         5       2       2.0     Undefined
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 3            1333.0           1             0           0           0       0
# 5             654.0           0             0           0           0       0
# 9            2813.0           0             1           0           0       0
# 10           1194.0           0             0           0           0       0
# 15           2343.0           0             0           0           0       0
# ...             ...         ...           ...         ...         ...     ...
# 3156         2680.0           0             0           0           0       0
# 3158          450.0           0             0           0           0       0
# 3159         2000.0           0             0           0           0       0
# 3160         1650.0           0             0           0           0       0
# 3162         1350.0           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 3                   0            76
# 5                   0             0
# 9                   0           100
# 10                  0            49
# 15                  0            59
# ...               ...           ...
# 3156                0             0
# 3158                0             0
# 3159                0             0
# 3160                0             0
# 3162                0             0
#
# [419 rows x 18 columns]

# %%
def mode_based_imputation(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector']) & (df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1764
# New Property           642
# Moderately Old         561
# Old Property           317
# Under Construction     133
# Undefined               74
# Name: count, dtype: int64

# %%
def mode_based_imputation2(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation2,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1778
# New Property           647
# Moderately Old         564
# Old Property           328
# Under Construction     133
# Undefined               41
# Name: count, dtype: int64

# %%
def mode_based_imputation3(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation3,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1791
# New Property           647
# Moderately Old         592
# Old Property           328
# Under Construction     133
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.to_csv('gurgaon_properties_missing_value_imputation.csv',index=False)

# %%
df.shape
# Out:
# (3491, 18)
